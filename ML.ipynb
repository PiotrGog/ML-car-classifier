# %%
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# %cd /content/gdrive/My\ Drive/ML_car

# %%
# !git clone https://github.com/PiotrGog/ML-car-classifier

# %%
# %cd /content/

# %%
# !chmod +x /content/gdrive/My\ Drive/ML_car/ML-car-classifier/download_data.sh

# %%
# !/content/gdrive/My\ Drive/ML_car/ML-car-classifier/download_data.sh

# %%
# !chmod +x /content/gdrive/My\ Drive/ML_car/ML-car-classifier/generate_data.sh

# %%
# !python /content/gdrive/My\ Drive/ML_car/ML-car-classifier/generate_data.py \
    "./resources/pa3_images/train/car" \
    "./resources/pa3_images/train_augmentation/car" \
    16000

# %%
# !python /content/gdrive/My\ Drive/ML_car/ML-car-classifier/generate_data.py \
    "./resources/pa3_images/train/other" \
    "./resources/pa3_images/train_augmentation/other" \
    16000

# %%
# !chmod +x /content/gdrive/My\ Drive/ML_car/ML-car-classifier/train_google_save_best.sh

# %%
# !/content/gdrive/My\ Drive/ML_car/ML-car-classifier/train_google_save_best.sh
